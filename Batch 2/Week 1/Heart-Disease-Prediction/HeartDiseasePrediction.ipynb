# %% [markdown]
# # Heart Disease Prediction - 11-Step Machine Learning Pipeline
# **Author:** Sardar Ahmed
# **Internship:** Alphatron Technologies Research Internship (Batch 2 - Week 1)
# **Dataset:** UCI Heart Disease Dataset (920 Patient Records, 16 Features)

# %% [markdown]
# ## Step 1: Data Preparation & Cleaning

# %%
from Step_1_DataPreparation import run_data_preparation
df_cleaned = run_data_preparation()
df_cleaned.head()

# %% [markdown]
# ## Step 2: Exploratory Data Analysis (EDA)

# %%
from Step_2_EDA import run_eda
run_eda()

# %% [markdown]
# ## Step 3: Data Transformation & Feature Encoding

# %%
from Step_3_Data_Transformation import run_data_transformation
df_transformed = run_data_transformation()
df_transformed.head()

# %% [markdown]
# ## Step 4: Feature Selection

# %%
from Step_4_FeatureSelection import run_feature_selection
df_selected = run_feature_selection()
df_selected.head()

# %% [markdown]
# ## Step 5: Stratified Train / Test Data Split

# %%
from Step_5_Train_Test_DataSplit import run_data_split
X_train, X_test, y_train, y_test = run_data_split()

# %% [markdown]
# ## Step 6: Baseline Model Training

# %%
from Step_6_Model_Training import run_model_training
run_model_training()

# %% [markdown]
# ## Step 7: Model Testing & Performance Evaluation

# %%
from Step_7_ModelTesting_Performceevaluation import run_model_evaluation
eval_results = run_model_evaluation()

# %% [markdown]
# ## Step 8: Data Sampling & Class Balancing (SMOTE)

# %%
from Step_8_DataSampling import run_data_sampling
X_sampled, y_sampled = run_data_sampling()

# %% [markdown]
# ## Step 9: 5-Fold Stratified Cross-Validation

# %%
from Step_9_Cross_Validation import run_cross_validation
run_cross_validation()

# %% [markdown]
# ## Step 10: Hyperparameter Optimization (GridSearchCV)

# %%
from Step_10_HyperparameterOptimization import run_hyperparameter_optimization
best_xgb = run_hyperparameter_optimization()

# %% [markdown]
# ## Step 11: Model Comparison & Final Selection

# %%
from Step_11_Model_Comparison import run_model_comparison
run_model_comparison()
